# %% [markdown]
# <a href="https://colab.research.google.com/github/csumithra/COVID-19/blob/master/BusCar_ObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pythonlessons/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 439, done.
# remote: Total 439 (delta 0), reused 0 (delta 0), pack-reused 439
# Receiving objects: 100% (439/439), 34.09 MiB | 21.71 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
# !ls
# Out:
# OIDv4_ToolKit  sample_data

# %%
# !pip install -r '/content/OIDv4_ToolKit/requirements.txt'
# Out:
# ...
#      |████████████████████████████████| 3.0MB 8.1MB/s
# ...
#      |████████████████████████████████| 6.2MB 55.7MB/s
# ...
#      |████████████████████████████████| 51kB 9.5MB/s
# ...
#   Found existing installation: botocore 1.16.10
#     Uninstalling botocore-1.16.10:
#       Successfully uninstalled botocore-1.16.10
#   Found existing installation: rsa 4.0
#     Uninstalling rsa-4.0:
#       Successfully uninstalled rsa-4.0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import argparse
import configparser

import io
import os
import shutil

import random
from collections import defaultdict 

import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.2.0

# %%
# !python '/content/OIDv4_ToolKit/main.py' downloader --classes Car Bus --type_csv train --limit 400
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Car.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 56918 KB/s, 0 seconds passed
# ...

# %%
## Move OID into OIDv4_ToolKit
# !pwd
# Out:
# /content

# %%
print(len(os.listdir('/content/OIDv4_ToolKit/OID/Dataset/train/Bus')))

print(len(os.listdir('/content/OIDv4_ToolKit/OID/Dataset/train/Car')))
# Out:
# 401
# 401

# %%
## change the oid_to_pascal_voc_xml.py - os.chdir(os.path.join("/content/OIDv4_ToolKit/OID", "Dataset"))
# Out:
# classes.txt  LICENSE  modules  oid_to_pascal_voc_xml.py  requirements.txt
# images	     main.py  OID      README.md		 voc_to_YOLOv3.py

# %%
# !python '/content/OIDv4_ToolKit/oid_to_pascal_voc_xml.py' ## Convert label files to XML
# Out:
# Currently in Subdirectory: train
#
# Creating PASCAL VOC XML Files for Class: Car
# 100% 400/400 [00:04<00:00, 80.49it/s]
#
# Creating PASCAL VOC XML Files for Class: Bus
# 100% 400/400 [00:04<00:00, 80.44it/s]

# %%
print(len(os.listdir('/content/OIDv4_ToolKit/OID/Dataset/train/Bus')))

print(len(os.listdir('/content/OIDv4_ToolKit/OID/Dataset/train/Car')))
# Out:
# 801
# 801

# %%
#dataset_train = '/content/OIDv4_ToolKit/OID/Dataset/train/'
#dataset_file = '/content/OIDv4_ToolKit/2_CLASS_test.txt'


## In For loop, make this change --> fullname = CLASS+'/'+filename

# %%
# !python '/content/OIDv4_ToolKit/voc_to_YOLOv3.py' ## Converting XML to YOLO v3 file structure

# %%
# !git clone https://github.com/pythonlessons/YOLOv3-object-detection-tutorial
# Out:
# Cloning into 'YOLOv3-object-detection-tutorial'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 154 (delta 35), reused 1 (delta 0), pack-reused 74
# Receiving objects: 100% (154/154), 218.16 MiB | 37.11 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !ls '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training' ## move the two 2_CLASS files to this dir
# Out:
# 2_CLASS_test_classes.txt  hydrant2.jpg	      train_bottleneck.py
# 2_CLASS_test.txt	  hydrant.jpg	      train.py
# 4_CLASS_test_classes.txt  image_detect.py     webcam_detect.py
# 4_CLASS_test.txt	  model_data	      yolo3
# convert.py		  realtime_detect.py

# %%
## Copy yolov3.weights from google drive to model_data folder

# %%
from google.colab import drive

drive.mount('/content/drive/', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls '/content/drive/My Drive/Kaggle' ## check for weights file
# Out:
#  BusCar_ObjectDetection.ipynb	     ProstrateCancer_Competition
# 'Global Wheat Detection'	     yolov3.weights
#  Kaggle_StockData_TimeSeries.ipynb

# %%
# !cp -av '/content/drive/My Drive/Kaggle/yolov3.weights' '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data' ## copy
# Out:
# '/content/drive/My Drive/Kaggle/yolov3.weights' -> '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data/yolov3.weights'

# %%
# !ls '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data' ## check after copy
# Out:
# coco_classes.txt       yolo_anchors.txt  yolov3.weights
# tiny_yolo_anchors.txt  yolov3.cfg

# %%
## !wget https://pjreddie.com/media/files/yolov3.weights

# %%
## Convert the Darknet YOLO model to a Keras model

# !python '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/convert.py' /content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data/yolov3.cfg /content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data/yolov3.weights /content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data/yolo_weights.h5
# Out:
# Using TensorFlow backend.
# 2020-05-20 14:09:24.891237: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-05-20 14:09:26.877976: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-20 14:09:26.942620: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-20 14:09:26.943441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# ...

# %%
## Edit py file to change the path 
#def _main():
    # annotation_path = '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/2_CLASS_test.txt'
    # log_dir = '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/logs/000/'
    # classes_path = '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/2_CLASS_test_classes.txt'
    # anchors_path = '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data/yolo_anchors.txt'

## and model_path

# from tensorflow.python.ops import control_flow_ops in /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py

# !python '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/train.py'
# Out:
# Using TensorFlow backend.
# 2020-05-20 14:21:34.779278: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-20 14:21:36.736556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-20 14:21:36.758663: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-20 14:21:36.759525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-05-20 14:21:36.759588: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
## Detect new images

# "model_path": '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/logs/000/trained_weights_final.h5',
# "anchors_path": '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/model_data/yolo_anchors.txt',
# "classes_path": '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/2_CLASS_test_classes.txt',
        
# self.sess = tf.compat.v1.Session()

#!python '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/image_detect.py'

# %%
#!python '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/myobj_detect.py'

# %%
# !python '/content/YOLOv3-object-detection-tutorial/YOLOv3-custom-training/new_obj_detect.py'
# Out:
# 2020-05-20 16:01:24.908883: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# START INIT
# 2020-05-20 16:01:26.966653: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-20 16:01:26.969402: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-05-20 16:01:26.969453: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: ead262739880
# 2020-05-20 16:01:26.969480: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: ead262739880
# 2020-05-20 16:01:26.969597: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 418.67.0
# ...
